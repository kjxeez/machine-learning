# %% [markdown]
# <a href="https://colab.research.google.com/github/kjxeez/machine-learning/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("/content/data-49159-2023-03-17.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.drop(index=0, inplace=True)

# %%
df
# Out:
#            ID   Period   global_id            StationName  \
# 1           1  02.2016   272777248         Лосиный остров
# 2           2  02.2016   272777249             Глебовская
# 3           3  02.2016   272777250             Глебовская
# 4           4  02.2016   272777251             Глебовская
# 5           5  02.2016   272777252             Глебовская
# ...       ...      ...         ...                    ...
# 24799  708527  02.2023  2577707577  Пролетарский проспект
# 24800  708528  02.2023  2577707578  Пролетарский проспект
# 24801  708529  02.2023  2577707579  Пролетарский проспект
# 24802  708530  02.2023  2577707580  Пролетарский проспект
# 24803  708531  02.2023  2577707582  Пролетарский проспект
#
#                      SurveillanceZoneCharacteristics  \
# 1                               Природные территории
# 2      Смешанные антропогенные источники загрязнений
# 3      Смешанные антропогенные источники загрязнений
# 4      Смешанные антропогенные источники загрязнений
# 5      Смешанные антропогенные источники загрязнений
# ...                                              ...
# 24799  Смешанные антропогенные источники загрязнений
# 24800  Смешанные антропогенные источники загрязнений
# 24801  Смешанные антропогенные источники загрязнений
# 24802  Смешанные антропогенные источники загрязнений
# 24803  Смешанные антропогенные источники загрязнений
#
#                                 AdmArea            District  \
# 1      Восточный административный округ  район Метрогородок
# 2      Восточный административный округ   район Богородское
# 3      Восточный административный округ   район Богородское
# 4      Восточный административный округ   район Богородское
# 5      Восточный административный округ   район Богородское
# ...                                 ...                 ...
# 24799      Южный административный округ      район Царицыно
# 24800      Южный административный округ      район Царицыно
# 24801      Южный административный округ      район Царицыно
# 24802      Южный административный округ      район Царицыно
# 24803      Южный административный округ      район Царицыно
#
#                                                 Location  \
# 1                       улица Ротерта, дом 4, строение 5
# 2                      Глебовская улица, дом 3, корпус 1
# 3                      Глебовская улица, дом 3, корпус 1
# 4                      Глебовская улица, дом 3, корпус 1
# 5                      Глебовская улица, дом 3, корпус 1
# ...                                                  ...
# 24799  Российская Федерация, город Москва, внутригоро...
# 24800  Российская Федерация, город Москва, внутригоро...
# 24801  Российская Федерация, город Москва, внутригоро...
# 24802  Российская Федерация, город Москва, внутригоро...
# 24803  Российская Федерация, город Москва, внутригоро...
#
#                       Parameter MonthlyAverage  ... ID_en Period_en  \
# 1                Оксид углерода           0.19  ...   NaN       NaN
# 2                Оксид углерода           0.32  ...   NaN       NaN
# 3                   Сероводород              0  ...   NaN       NaN
# 4                   Оксид азота              0  ...   NaN       NaN
# 5                 Диоксид азота              0  ...   NaN       NaN
# ...                         ...            ...  ...   ...       ...
# 24799            Оксид углерода            0.2  ...   NaN       NaN
# 24800               Оксид азота              0  ...   NaN       NaN
# 24801             Диоксид азота              0  ...   NaN       NaN
# 24802   Взвешенные частицы РМ10              0  ...   NaN       NaN
# 24803  Взвешенные частицы РМ2.5              0  ...   NaN       NaN
#
#       StationName_en SurveillanceZoneCharacteristics_en AdmArea_en  \
# 1                NaN                                NaN        NaN
# 2                NaN                                NaN        NaN
# 3                NaN                                NaN        NaN
# 4                NaN                                NaN        NaN
# 5                NaN                                NaN        NaN
# ...              ...                                ...        ...
# 24799            NaN                                NaN        NaN
# 24800            NaN                                NaN        NaN
# 24801            NaN                                NaN        NaN
# 24802            NaN                                NaN        NaN
# 24803            NaN                                NaN        NaN
#
#       District_en Location_en Parameter_en MonthlyAverage_en  \
# 1             NaN         NaN          NaN               NaN
# 2             NaN         NaN          NaN               NaN
# 3             NaN         NaN          NaN               NaN
# 4             NaN         NaN          NaN               NaN
# 5             NaN         NaN          NaN               NaN
# ...           ...         ...          ...               ...
# 24799         NaN         NaN          NaN               NaN
# 24800         NaN         NaN          NaN               NaN
# 24801         NaN         NaN          NaN               NaN
# 24802         NaN         NaN          NaN               NaN
# 24803         NaN         NaN          NaN               NaN
#
#       MonthlyAveragePDKss_en
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# ...                      ...
# 24799                    NaN
# 24800                    NaN
# 24801                    NaN
# 24802                    NaN
# 24803                    NaN
#
# [24803 rows x 21 columns]

# %% [markdown]
# # __EDA__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24803 entries, 1 to 24803
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  24803 non-null  object
#  1   Period                              24803 non-null  object
#  2   global_id                           24803 non-null  object
#  3   StationName                         24803 non-null  object
#  4   SurveillanceZoneCharacteristics     24803 non-null  object
#  5   AdmArea                             24803 non-null  object
#  6   District                            24803 non-null  object
#  7   Location                            24803 non-null  object
#  8   Parameter                           24803 non-null  object
#  9   MonthlyAverage                      24803 non-null  object
#  10  MonthlyAveragePDKss                 14880 non-null  object
#  11  ID_en                               0 non-null      object
#  12  Period_en                           0 non-null      object
#  13  StationName_en                      0 non-null      object
#  14  SurveillanceZoneCharacteristics_en  0 non-null      object
#  15  AdmArea_en                          0 non-null      object
#  16  District_en                         0 non-null      object
#  17  Location_en                         0 non-null      object
#  18  Parameter_en                        0 non-null      object
#  19  MonthlyAverage_en                   0 non-null      object
#  20  MonthlyAveragePDKss_en              0 non-null      object
# dtypes: object(21)
# memory usage: 4.0+ MB

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24803 entries, 1 to 24803
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               24803 non-null  object
#  1   Period                           24803 non-null  object
#  2   global_id                        24803 non-null  object
#  3   StationName                      24803 non-null  object
#  4   SurveillanceZoneCharacteristics  24803 non-null  object
#  5   AdmArea                          24803 non-null  object
#  6   District                         24803 non-null  object
#  7   Location                         24803 non-null  object
#  8   Parameter                        24803 non-null  object
#  9   MonthlyAverage                   24803 non-null  object
#  10  MonthlyAveragePDKss              14880 non-null  object
# dtypes: object(11)
# memory usage: 2.1+ MB

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<1.11,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<2,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (3.7.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.10.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.22.4)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (2.27.1)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (0.13.5)
# Requirement already satisfied: typeguard<3,>=2.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling==0.0.dev0) (1.8.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling==0.0.dev0) (8.4.0)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling==0.0.dev0) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==0.0.dev0) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.2->ydata-profiling==0.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling==0.0.dev0) (2022.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling==0.0.dev0) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.8.1->ydata-profiling==0.0.dev0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling==0.0.dev0) (3.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling==0.0.dev0) (1.16.0)

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-46d906157b50> in <cell line: 2>()
#       1 profile = ProfileReport(df)
# ----> 2 profile.to_notebook_iframe()
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in to_notebook_iframe(self)
#     496         with warnings.catch_warnings():
#     497             warnings.simplefilter("ignore")
# --> 498             display(get_notebook_iframe(self.config, self))
#     499
#     500     def to_widgets(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe(config, profile)
#      73         output = get_notebook_iframe_src(config, profile)
#      74     elif attribute == IframeAttribute.srcdoc:
# ---> 75         output = get_notebook_iframe_srcdoc(config, profile)
#      76     else:
#      77         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe_srcdoc(config, profile)
#      27     width = config.notebook.iframe.width
#      28     height = config.notebook.iframe.height
# ---> 29     src = html.escape(profile.to_html())
#      30
#      31     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in to_html(self)
#     466
#     467         """
# --> 468         return self.html
#     469
#     470     def to_json(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in html(self)
#     273     def html(self) -> str:
#     274         if self._html is None:
# --> 275             self._html = self._render_html()
#     276         return self._html
#     277
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in _render_html(self)
#     381         from ydata_profiling.report.presentation.flavours import HTMLReport
#     382
# --> 383         report = self.report
#     384
#     385         with tqdm(
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in report(self)
#     267     def report(self) -> Root:
#     268         if self._report is None:
# --> 269             self._report = get_report_structure(self.config, self.description_set)
#     270         return self._report
#     271
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/report/structure/report.py in get_report_structure(config, summary)
#     384                     items=list(summary.variables),
#     385                     item=Container(
# --> 386                         render_variables_section(config, summary),
#     387                         sequence_type="accordion",
#     388                         name="Variables",
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/report/structure/report.py in render_variables_section(config, dataframe_summary)
#     159             variable_type = summary["type"]
#     160         render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 161         template_variables.update(render_map_type(config, template_variables))
#     162
#     163         # Ignore these
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/report/structure/variables/render_text.py in render_text(config, summary)
#      74     if words and "word_counts" in summary:
#      75         mini_wordcloud = Image(
# ---> 76             plot_word_cloud(config, summary["word_counts"]),
#      77             image_format=config.plot.image_format,
#      78             alt="Mini wordcloud",
#
# /usr/lib/python3.10/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/plot.py in plot_word_cloud(config, word_counts)
#     117 @manage_matplotlib_context()
#     118 def plot_word_cloud(config: Settings, word_counts: pd.Series) -> str:
# --> 119     _plot_word_cloud(series=word_counts)
#     120     return plot_360_n0sc0pe(config)
#     121
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/plot.py in _plot_word_cloud(series, figsize)
#      33     wordcloud = WordCloud(
#      34         background_color="white", random_state=123, width=300, height=200, scale=2
# ---> 35     ).generate_from_frequencies(word_dict)
#      36     plt.figure(figsize=figsize)
#      37     plot = plt.imshow(wordcloud, interpolation="bilinear")
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     506                     font, orientation=orientation)
#     507                 # get size of resulting text
# --> 508                 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     509                 # find possible places using integral image:
#     510                 result = occupancy.sample_position(box_size[3] + self.margin,
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageDraw.py in textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color)
#     649             font = self.getfont()
#     650         if not isinstance(font, ImageFont.FreeTypeFont):
# --> 651             raise ValueError("Only supported for TrueType fonts")
#     652         mode = "RGBA" if embedded_color else self.fontmode
#     653         bbox = font.getbbox(
#
# ValueError: Only supported for TrueType fonts

# %%
df
# Out:
#            ID   Period   global_id            StationName  \
# 1           1  02.2016   272777248         Лосиный остров
# 2           2  02.2016   272777249             Глебовская
# 3           3  02.2016   272777250             Глебовская
# 4           4  02.2016   272777251             Глебовская
# 5           5  02.2016   272777252             Глебовская
# ...       ...      ...         ...                    ...
# 24799  708527  02.2023  2577707577  Пролетарский проспект
# 24800  708528  02.2023  2577707578  Пролетарский проспект
# 24801  708529  02.2023  2577707579  Пролетарский проспект
# 24802  708530  02.2023  2577707580  Пролетарский проспект
# 24803  708531  02.2023  2577707582  Пролетарский проспект
#
#                      SurveillanceZoneCharacteristics  \
# 1                               Природные территории
# 2      Смешанные антропогенные источники загрязнений
# 3      Смешанные антропогенные источники загрязнений
# 4      Смешанные антропогенные источники загрязнений
# 5      Смешанные антропогенные источники загрязнений
# ...                                              ...
# 24799  Смешанные антропогенные источники загрязнений
# 24800  Смешанные антропогенные источники загрязнений
# 24801  Смешанные антропогенные источники загрязнений
# 24802  Смешанные антропогенные источники загрязнений
# 24803  Смешанные антропогенные источники загрязнений
#
#                                 AdmArea            District  \
# 1      Восточный административный округ  район Метрогородок
# 2      Восточный административный округ   район Богородское
# 3      Восточный административный округ   район Богородское
# 4      Восточный административный округ   район Богородское
# 5      Восточный административный округ   район Богородское
# ...                                 ...                 ...
# 24799      Южный административный округ      район Царицыно
# 24800      Южный административный округ      район Царицыно
# 24801      Южный административный округ      район Царицыно
# 24802      Южный административный округ      район Царицыно
# 24803      Южный административный округ      район Царицыно
#
#                                                 Location  \
# 1                       улица Ротерта, дом 4, строение 5
# 2                      Глебовская улица, дом 3, корпус 1
# 3                      Глебовская улица, дом 3, корпус 1
# 4                      Глебовская улица, дом 3, корпус 1
# 5                      Глебовская улица, дом 3, корпус 1
# ...                                                  ...
# 24799  Российская Федерация, город Москва, внутригоро...
# 24800  Российская Федерация, город Москва, внутригоро...
# 24801  Российская Федерация, город Москва, внутригоро...
# 24802  Российская Федерация, город Москва, внутригоро...
# 24803  Российская Федерация, город Москва, внутригоро...
#
#                       Parameter MonthlyAverage MonthlyAveragePDKss
# 1                Оксид углерода           0.19                   0
# 2                Оксид углерода           0.32                0.11
# 3                   Сероводород              0                 NaN
# 4                   Оксид азота              0                0.23
# 5                 Диоксид азота              0                0.59
# ...                         ...            ...                 ...
# 24799            Оксид углерода            0.2                   0
# 24800               Оксид азота              0                 NaN
# 24801             Диоксид азота              0                0.34
# 24802   Взвешенные частицы РМ10              0                0.22
# 24803  Взвешенные частицы РМ2.5              0                0.33
#
# [24803 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

plt.figure(figsize=(28, 10))
ax = sns.countplot(x="AdmArea", data=df, palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Out:
# [Text(0, 0, 'Административный округ'),
#  Text(1, 0, 'Восточный административный округ'),
#  Text(2, 0, 'Западный административный округ'),
#  Text(3, 0, 'Зеленоградский административный округ'),
#  Text(4, 0, 'Новомосковский административный округ'),
#  Text(5, 0, 'Северный административный округ'),
#  Text(6, 0, 'Северо-Восточный административный округ'),
#  Text(7, 0, 'Северо-Западный административный округ'),
#  Text(8, 0, 'Троицкий административный округ'),
#  Text(9, 0, 'Центральный административный округ'),
#  Text(10, 0, 'Юго-Восточный административный округ'),
#  Text(11, 0, 'Юго-Западный административный округ'),
#  Text(12, 0, 'Южный административный округ')]

# %%
toppar = pd.value_counts(df['Parameter'])
toppar
# Out:
# Оксид углерода                                       3431
# Диоксид азота                                        3197
# Оксид азота                                          2933
# Сумма углеводородных соединений за вычетом метана    2022
# Сумма углеводородных соединений                      2021
# Метан                                                2021
# Сероводород                                          1565
# Диоксид серы                                         1430
# Взвешенные частицы РМ10                              1236
# Взвешенные частицы РМ2.5                             1133
# Озон                                                  980
# Взвешенные частицы РМ10 (суточные измерения)          401
# Взвешенные частицы РМ2.5 (суточные измерения)         322
# C6H6 (бензол)                                         298
# Диоксид углерода                                      292
# CH2O (формальдегид)                                   286
# C6H5OH (фенол)                                        271
# Кислород                                              223
# Аммиак                                                214
# C10H8 (нафталин)                                      180
# C7H8 (толуол)                                         180
# C8H8 (стирол)                                         167
# Name: Parameter, dtype: int64

# %%
from plotly import graph_objects as go

fig = go.Figure([
        go.Bar(x=toppar.index, y=toppar.values, text=toppar.values, marker_color='indianred')
])

fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d830ed8b-5446-4f98-9f7c-aa70ab498215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d830ed8b-5446-4f98-9f7c-aa70ab498215")) {                    Plotly.newPlot(                        "d830ed8b-5446-4f98-9f7c-aa70ab498215",                        [{"marker":{"color":"indianred"},"text":[3431.0,3197.0,2933.0,2022.0,2021.0,2021.0,1565.0,1430.0,1236.0,1133.0,980.0,401.0,322.0,298.0,292.0,286.0,271.0,223.0,214.0,180.0,180.0,167.0],"x":["\u041e\u043a\u0441\u0438\u0434 \u0443\u0433\u043b\u0435\u0440\u043e\u0434\u0430","\u0414\u0438\u043e\u043a\u0441\u0438\u0434 \u0430\u0437\u043e\u0442\u0430","\u041e\u043a\u0441\u0438\u0434 \u0430\u0437\u043e\u0442\u0430","\u0421\u0443\u043c\u043c\u0430 \u0443\u0433\u043b\u0435\u0432\u043e\u0434\u043e\u0440\u043e\u0434\u043d\u044b\u0445 \u0441\u043e\u0435\u0434\u0438\u043d\u0435\u043d\u0438\u0439 \u0437\u0430 \u0432\u044b\u0447\u0435\u0442\u043e\u043c \u043c\u0435\u0442\u0430\u043d\u0430","\u0421\u0443\u043c\u043c\u0430 \u0443\u0433\u043b\u0435\u0432\u043e\u0434\u043e\u0440\u043e\u0434\u043d\u044b\u0445 \u0441\u043e\u0435\u0434\u0438\u043d\u0435\u043d\u0438\u0439","\u041c\u0435\u0442\u0430\u043d","\u0421\u0435\u0440\u043e\u0432\u043e\u0434\u043e\u0440\u043e\u0434","\u0414\u0438\u043e\u043a\u0441\u0438\u0434 \u0441\u0435\u0440\u044b","\u0412\u0437\u0432\u0435\u0448\u0435\u043d\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438\u0446\u044b \u0420\u041c10","\u0412\u0437\u0432\u0435\u0448\u0435\u043d\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438\u0446\u044b \u0420\u041c2.5","\u041e\u0437\u043e\u043d","\u0412\u0437\u0432\u0435\u0448\u0435\u043d\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438\u0446\u044b \u0420\u041c10 (\u0441\u0443\u0442\u043e\u0447\u043d\u044b\u0435 \u0438\u0437\u043c\u0435\u0440\u0435\u043d\u0438\u044f)","\u0412\u0437\u0432\u0435\u0448\u0435\u043d\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438\u0446\u044b \u0420\u041c2.5 (\u0441\u0443\u0442\u043e\u0447\u043d\u044b\u0435 \u0438\u0437\u043c\u0435\u0440\u0435\u043d\u0438\u044f)","C6H6 (\u0431\u0435\u043d\u0437\u043e\u043b)","\u0414\u0438\u043e\u043a\u0441\u0438\u0434 \u0443\u0433\u043b\u0435\u0440\u043e\u0434\u0430","CH2O (\u0444\u043e\u0440\u043c\u0430\u043b\u044c\u0434\u0435\u0433\u0438\u0434)","C6H5OH (\u0444\u0435\u043d\u043e\u043b)","\u041a\u0438\u0441\u043b\u043e\u0440\u043e\u0434","\u0410\u043c\u043c\u0438\u0430\u043a","C10H8 (\u043d\u0430\u0444\u0442\u0430\u043b\u0438\u043d)","C7H8 (\u0442\u043e\u043b\u0443\u043e\u043b)","C8H8 (\u0441\u0442\u0438\u0440\u043e\u043b)"],"y":[3431,3197,2933,2022,2021,2021,1565,1430,1236,1133,980,401,322,298,292,286,271,223,214,180,180,167],"type":"bar","textposition":"outside","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...
